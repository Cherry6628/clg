# %% [markdown]
# Ex.No:4 Implement a Feed-Forward Network in
# TensorFlow/Keras

# %% [markdown]
# Aim:
# To write a python coding to implement Feed-Forward Network in TensorFlow/Keras.

# %%
# import the necessary packages
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
import argparse

# construct the argument parse and parse the arguments
ap = argparse.ArgumentParser()
ap.add_argument("-o", "--output", required=True, help="path to the output loss/accuracy plot")
args = ap.parse_args(["--output", "04_keras_mnist.png"])

# grab the MNIST dataset
print("[INFO] accessing MNIST...")
((trainX, trainY), (testX, testY)) = mnist.load_data()

# each image in the MNIST dataset is represented as a 28x28x1 image, but in order to apply a standard neural network we must first "flatten" the image to be simple list of 28x28=784 pixels
trainX = trainX.reshape((trainX.shape[0], 28 * 28 * 1))
testX = testX.reshape((testX.shape[0], 28 * 28 * 1))

# scale data to the range of [0, 1]
trainX = trainX.astype("float32") / 255.0
testX = testX.astype("float32") / 255.0

# convert the labels from integers to vectors
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# define the 784-256-128-10 architecture using Keras
model = Sequential()
model.add(Dense(256, input_shape=(784,), activation="sigmoid"))
model.add(Dense(128, activation="sigmoid"))
model.add(Dense(10, activation="softmax"))

# train the model using SGD
print("[INFO] training network...")
sgd = SGD(0.01)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=100, batch_size=128)

# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=128)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=[str(x) for x in lb.classes_]))

# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 100), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 100), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 100), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig(args.output)
# Out:
# [INFO] accessing MNIST...
# [INFO] training network...
# Epoch 1/100
# D:\_z_\Anaconda_Projects\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1555 - loss: 2.3153 - val_accuracy: 0.3083 - val_loss: 2.2377
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3370 - loss: 2.2214 - val_accuracy: 0.4935 - val_loss: 2.1591
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4872 - loss: 2.1395 - val_accuracy: 0.5944 - val_loss: 2.0476
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5622 - loss: 2.0179 - val_accuracy: 0.5986 - val_loss: 1.8858
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5970 - loss: 1.8501 - val_accuracy: 0.5940 - val_loss: 1.6784
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6314 - loss: 1.6361 - val_accuracy: 0.6998 - val_loss: 1.4581
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6914 - loss: 1.4239 - val_accuracy: 0.7345 - val_loss: 1.2645
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7324 - loss: 1.2437 - val_accuracy: 0.7567 - val_loss: 1.1083
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7590 - loss: 1.0935 - val_accuracy: 0.7802 - val_loss: 0.9832
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7779 - loss: 0.9764 - val_accuracy: 0.7924 - val_loss: 0.8839
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7974 - loss: 0.8790 - val_accuracy: 0.8096 - val_loss: 0.8036
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8116 - loss: 0.8060 - val_accuracy: 0.8211 - val_loss: 0.7390
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8221 - loss: 0.7436 - val_accuracy: 0.8362 - val_loss: 0.6861
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8318 - loss: 0.6913 - val_accuracy: 0.8445 - val_loss: 0.6427
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8397 - loss: 0.6483 - val_accuracy: 0.8494 - val_loss: 0.6061
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8455 - loss: 0.6146 - val_accuracy: 0.8539 - val_loss: 0.5750
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8539 - loss: 0.5833 - val_accuracy: 0.8586 - val_loss: 0.5495
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8553 - loss: 0.5641 - val_accuracy: 0.8653 - val_loss: 0.5260
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8613 - loss: 0.5354 - val_accuracy: 0.8666 - val_loss: 0.5066
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8636 - loss: 0.5199 - val_accuracy: 0.8715 - val_loss: 0.4887
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8688 - loss: 0.5025 - val_accuracy: 0.8745 - val_loss: 0.4737
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8699 - loss: 0.4928 - val_accuracy: 0.8764 - val_loss: 0.4602
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8769 - loss: 0.4698 - val_accuracy: 0.8800 - val_loss: 0.4476
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8760 - loss: 0.4613 - val_accuracy: 0.8830 - val_loss: 0.4371
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8801 - loss: 0.4515 - val_accuracy: 0.8843 - val_loss: 0.4269
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8833 - loss: 0.4403 - val_accuracy: 0.8852 - val_loss: 0.4178
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8818 - loss: 0.4372 - val_accuracy: 0.8880 - val_loss: 0.4094
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8848 - loss: 0.4252 - val_accuracy: 0.8885 - val_loss: 0.4018
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8875 - loss: 0.4139 - val_accuracy: 0.8891 - val_loss: 0.3956
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8879 - loss: 0.4092 - val_accuracy: 0.8908 - val_loss: 0.3893
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8916 - loss: 0.3955 - val_accuracy: 0.8924 - val_loss: 0.3833
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8919 - loss: 0.3923 - val_accuracy: 0.8939 - val_loss: 0.3777
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8921 - loss: 0.3916 - val_accuracy: 0.8954 - val_loss: 0.3735
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8931 - loss: 0.3856 - val_accuracy: 0.8967 - val_loss: 0.3685
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8947 - loss: 0.3781 - val_accuracy: 0.8974 - val_loss: 0.3650
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8958 - loss: 0.3733 - val_accuracy: 0.8978 - val_loss: 0.3600
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8945 - loss: 0.3773 - val_accuracy: 0.8976 - val_loss: 0.3569
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8951 - loss: 0.3725 - val_accuracy: 0.8993 - val_loss: 0.3531
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9003 - loss: 0.3561 - val_accuracy: 0.8987 - val_loss: 0.3496
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8999 - loss: 0.3623 - val_accuracy: 0.9012 - val_loss: 0.3465
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8974 - loss: 0.3611 - val_accuracy: 0.9014 - val_loss: 0.3432
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8994 - loss: 0.3547 - val_accuracy: 0.9024 - val_loss: 0.3405
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9013 - loss: 0.3500 - val_accuracy: 0.9032 - val_loss: 0.3385
# Epoch 44/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8989 - loss: 0.3531 - val_accuracy: 0.9033 - val_loss: 0.3352
# Epoch 45/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9013 - loss: 0.3482 - val_accuracy: 0.9048 - val_loss: 0.3334
# Epoch 46/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9024 - loss: 0.3446 - val_accuracy: 0.9043 - val_loss: 0.3302
# Epoch 47/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9023 - loss: 0.3474 - val_accuracy: 0.9049 - val_loss: 0.3287
# Epoch 48/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9037 - loss: 0.3369 - val_accuracy: 0.9055 - val_loss: 0.3259
# Epoch 49/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9040 - loss: 0.3378 - val_accuracy: 0.9053 - val_loss: 0.3236
# Epoch 50/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9050 - loss: 0.3317 - val_accuracy: 0.9069 - val_loss: 0.3223
# Epoch 51/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9042 - loss: 0.3348 - val_accuracy: 0.9063 - val_loss: 0.3199
# Epoch 52/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9041 - loss: 0.3325 - val_accuracy: 0.9076 - val_loss: 0.3186
# Epoch 53/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9049 - loss: 0.3297 - val_accuracy: 0.9072 - val_loss: 0.3160
# Epoch 54/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9069 - loss: 0.3278 - val_accuracy: 0.9085 - val_loss: 0.3145
# Epoch 55/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9067 - loss: 0.3310 - val_accuracy: 0.9095 - val_loss: 0.3129
# Epoch 56/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9078 - loss: 0.3217 - val_accuracy: 0.9095 - val_loss: 0.3109
# Epoch 57/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9093 - loss: 0.3172 - val_accuracy: 0.9104 - val_loss: 0.3097
# Epoch 58/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9079 - loss: 0.3216 - val_accuracy: 0.9105 - val_loss: 0.3079
# Epoch 59/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9078 - loss: 0.3187 - val_accuracy: 0.9105 - val_loss: 0.3064
# Epoch 60/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9085 - loss: 0.3197 - val_accuracy: 0.9115 - val_loss: 0.3050
# Epoch 61/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9072 - loss: 0.3183 - val_accuracy: 0.9104 - val_loss: 0.3033
# Epoch 62/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9090 - loss: 0.3162 - val_accuracy: 0.9124 - val_loss: 0.3021
# Epoch 63/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9088 - loss: 0.3160 - val_accuracy: 0.9130 - val_loss: 0.3006
# Epoch 64/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9096 - loss: 0.3129 - val_accuracy: 0.9119 - val_loss: 0.2994
# Epoch 65/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9119 - loss: 0.3079 - val_accuracy: 0.9133 - val_loss: 0.2986
# Epoch 66/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9107 - loss: 0.3109 - val_accuracy: 0.9137 - val_loss: 0.2974
# Epoch 67/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9109 - loss: 0.3100 - val_accuracy: 0.9145 - val_loss: 0.2960
# Epoch 68/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9126 - loss: 0.3053 - val_accuracy: 0.9149 - val_loss: 0.2942
# Epoch 69/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9138 - loss: 0.3005 - val_accuracy: 0.9143 - val_loss: 0.2930
# Epoch 70/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9127 - loss: 0.2998 - val_accuracy: 0.9155 - val_loss: 0.2921
# Epoch 71/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9131 - loss: 0.3015 - val_accuracy: 0.9155 - val_loss: 0.2913
# Epoch 72/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9142 - loss: 0.3000 - val_accuracy: 0.9157 - val_loss: 0.2897
# Epoch 73/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9141 - loss: 0.2991 - val_accuracy: 0.9156 - val_loss: 0.2893
# Epoch 74/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9127 - loss: 0.3019 - val_accuracy: 0.9163 - val_loss: 0.2879
# Epoch 75/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9138 - loss: 0.3002 - val_accuracy: 0.9159 - val_loss: 0.2868
# Epoch 76/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9153 - loss: 0.2925 - val_accuracy: 0.9174 - val_loss: 0.2857
# Epoch 77/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9142 - loss: 0.2989 - val_accuracy: 0.9169 - val_loss: 0.2845
# Epoch 78/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9140 - loss: 0.2987 - val_accuracy: 0.9173 - val_loss: 0.2840
# Epoch 79/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9163 - loss: 0.2906 - val_accuracy: 0.9175 - val_loss: 0.2824
# Epoch 80/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9157 - loss: 0.2870 - val_accuracy: 0.9177 - val_loss: 0.2819
# Epoch 81/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9153 - loss: 0.2909 - val_accuracy: 0.9181 - val_loss: 0.2808
# Epoch 82/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9137 - loss: 0.2941 - val_accuracy: 0.9186 - val_loss: 0.2799
# Epoch 83/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9179 - loss: 0.2859 - val_accuracy: 0.9189 - val_loss: 0.2790
# Epoch 84/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9166 - loss: 0.2880 - val_accuracy: 0.9187 - val_loss: 0.2779
# Epoch 85/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9152 - loss: 0.2932 - val_accuracy: 0.9194 - val_loss: 0.2773
# Epoch 86/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9162 - loss: 0.2868 - val_accuracy: 0.9196 - val_loss: 0.2762
# Epoch 87/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9174 - loss: 0.2828 - val_accuracy: 0.9198 - val_loss: 0.2754
# Epoch 88/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9187 - loss: 0.2816 - val_accuracy: 0.9194 - val_loss: 0.2747
# Epoch 89/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9189 - loss: 0.2809 - val_accuracy: 0.9201 - val_loss: 0.2739
# Epoch 90/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9181 - loss: 0.2839 - val_accuracy: 0.9202 - val_loss: 0.2727
# Epoch 91/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9210 - loss: 0.2736 - val_accuracy: 0.9208 - val_loss: 0.2721
# Epoch 92/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9182 - loss: 0.2814 - val_accuracy: 0.9205 - val_loss: 0.2712
# Epoch 93/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9209 - loss: 0.2749 - val_accuracy: 0.9204 - val_loss: 0.2704
# Epoch 94/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9196 - loss: 0.2745 - val_accuracy: 0.9211 - val_loss: 0.2695
# Epoch 95/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9201 - loss: 0.2741 - val_accuracy: 0.9216 - val_loss: 0.2688
# Epoch 96/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9213 - loss: 0.2710 - val_accuracy: 0.9214 - val_loss: 0.2681
# Epoch 97/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9200 - loss: 0.2725 - val_accuracy: 0.9212 - val_loss: 0.2674
# Epoch 98/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9204 - loss: 0.2760 - val_accuracy: 0.9220 - val_loss: 0.2669
# Epoch 99/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9213 - loss: 0.2700 - val_accuracy: 0.9225 - val_loss: 0.2656
# Epoch 100/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9224 - loss: 0.2679 - val_accuracy: 0.9223 - val_loss: 0.2653
# [INFO] evaluating network...
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       980
#            1       0.97      0.97      0.97      1135
#            2       0.93      0.89      0.91      1032
#            3       0.90      0.91      0.90      1010
#            4       0.92      0.93      0.92       982
#            5       0.90      0.87      0.88       892
#            6       0.93      0.94      0.94       958
#            7       0.93      0.93      0.93      1028
#            8       0.88      0.89      0.89       974
#            9       0.92      0.90      0.91      1009
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
