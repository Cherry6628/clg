# %%
# !pip install tensorflow-gpu
import tensorflow as tf
print(tf.__version__)

# !git clone https://github.com/tensorflow/models.git
# %cd /content/models/research

# !pwd

# !protoc object_detection/protos/*.proto --python_out=.
# !git clone https://github.com/cocodataset/cocoapi.git
# %cd cocoapi/PythonAPI
# !make
# !cp -r pycocotools /content/models/research
# %cd ..

# !python -m pip install .

# From within TensorFlow/models/research/
# !python object_detection/builders/model_builder_tf2_test.py

# %cd /content/trainingdemo/pre-trained-models
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# !tar -xvf ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# %cd /content/trainingdemo
# !ls

# Create train data:
# !python generate_tfrecord.py -x /content/trainingdemo/images/train -l /content/trainingdemo/annotations/label_map.pbtxt -o /content/trainingdemo/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x /content/trainingdemo/images/test -l /content/trainingdemo/annotations/label_map.pbtxt -o /content/trainingdemo/annotations/test.record

# %cd /content/trainingdemo
# !ls

# !python model_main_tf2.py --model_dir=/content/training_demo/models/my_ssd_resnet101_v1_fpn --pipeline_config_path=/content/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config

# %cd /content/trainingdemo
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path /content/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config --trained_checkpoint_dir /content/training_demo/models/my_ssd_resnet101_v1_fpn --output_directory /content/training_demo/exported_models/my_model
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [44 lines of output]
#   Traceback (most recent call last):
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\_vendor\packaging\requirements.py", line 35, in __init__
#       parsed = _parse_requirement(requirement_string)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 64, in parse_requirement
#       return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 82, in _parse_requirement
#       url, specifier, marker = _parse_requirement_details(tokenizer)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 126, in _parse_requirement_details
#       marker = _parse_requirement_marker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 147, in _parse_requirement_marker
#       tokenizer.raise_syntax_error(
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\_vendor\packaging\_tokenizer.py", line 165, in raise_syntax_error
#       raise ParserSyntaxError(
#   setuptools.extern.packaging._tokenizer.ParserSyntaxError: Expected end or semicolon (after name and no valid version specifier)
#       python_version>"3.7"
#                     ^
#
#   The above exception was the direct cause of the following exception:
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\HARISANJU\AppData\Local\Temp\pip-install-xv1riwoj\tensorflow-gpu_675836d68b68493189b4f4704619a588\setup.py", line 40, in <module>
#       setuptools.setup()
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\__init__.py", line 106, in setup
#       _install_setup_requires(attrs)
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\__init__.py", line 77, in _install_setup_requires
#       dist.parse_config_files(ignore_option_errors=True)
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\dist.py", line 900, in parse_config_files
#       self._finalize_requires()
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\dist.py", line 597, in _finalize_requires
#       self._move_install_requirements_markers()
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\dist.py", line 637, in _move_install_requirements_markers
#       inst_reqs = list(_reqs.parse(spec_inst_reqs))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\_z_\Anaconda_Projects\Lib\site-packages\setuptools\_vendor\packaging\requirements.py", line 37, in __init__
#       raise InvalidRequirement(str(e)) from e
#   setuptools.extern.packaging.requirements.InvalidRequirement: Expected end or semicolon (after name and no valid version specifier)
#       python_version>"3.7"
#                     ^
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# 2.16.1
# [WinError 3] The system cannot find the path specified: '/content/models/research'
# D:\_z_\Anaconda_Projects\_______temporary
# Cloning into 'models'...
# Updating files:  51% (1892/3699)
# Updating files:  52% (1924/3699)
# Updating files:  53% (1961/3699)
# Updating files:  54% (1998/3699)
# Updating files:  55% (2035/3699)
# Updating files:  56% (2072/3699)
# Updating files:  57% (2109/3699)
# Updating files:  58% (2146/3699)
# Updating files:  59% (2183/3699)
# Updating files:  60% (2220/3699)
# Updating files:  61% (2257/3699)
# Updating files:  62% (2294/3699)
# Updating files:  63% (2331/3699)
# Updating files:  64% (2368/3699)
# Updating files:  65% (2405/3699)
# Updating files:  66% (2442/3699)
# Updating files:  66% (2450/3699)
# Updating files:  66% (2456/3699)
# Updating files:  67% (2479/3699)
# Updating files:  68% (2516/3699)
# Updating files:  69% (2553/3699)
# Updating files:  69% (2579/3699)
# Updating files:  70% (2590/3699)
# Updating files:  71% (2627/3699)
# Updating files:  72% (2664/3699)
# Updating files:  73% (2701/3699)
# Updating files:  73% (2733/3699)
# Updating files:  74% (2738/3699)
# Updating files:  75% (2775/3699)
# Updating files:  76% (2812/3699)
# Updating files:  77% (2849/3699)
# Updating files:  78% (2886/3699)
# Updating files:  78% (2922/3699)
# Updating files:  79% (2923/3699)
# Updating files:  80% (2960/3699)
# Updating files:  81% (2997/3699)
# Updating files:  82% (3034/3699)
# Updating files:  83% (3071/3699)
# Updating files:  83% (3097/3699)
# Updating files:  84% (3108/3699)
# Updating files:  84% (3132/3699)
# Updating files:  85% (3145/3699)
# Updating files:  86% (3182/3699)
# Updating files:  86% (3183/3699)
# Updating files:  87% (3219/3699)
# Updating files:  88% (3256/3699)
# Updating files:  88% (3290/3699)
# Updating files:  89% (3293/3699)
# Updating files:  90% (3330/3699)
# Updating files:  90% (3340/3699)
# Updating files:  91% (3367/3699)
# Updating files:  91% (3380/3699)
# Updating files:  92% (3404/3699)
# Updating files:  93% (3441/3699)
# Updating files:  93% (3442/3699)
# Updating files:  93% (3443/3699)
# Updating files:  94% (3478/3699)
# Updating files:  95% (3515/3699)
# Updating files:  96% (3552/3699)
# Updating files:  97% (3589/3699)
# Updating files:  98% (3626/3699)
# Updating files:  98% (3629/3699)
# Updating files:  98% (3653/3699)
# Updating files:  98% (3655/3699)
# Updating files:  99% (3663/3699)
# Updating files: 100% (3699/3699)
# Updating files: 100% (3699/3699), done.
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.
# 'protoc' is not recognized as an internal or external command,
# operable program or batch file.
# D:\_z_\Anaconda_Projects\_______temporary\cocoapi\PythonAPI
# Cloning into 'cocoapi'...
# 'make' is not recognized as an internal or external command,
# operable program or batch file.
# D:\_z_\Anaconda_Projects\_______temporary\cocoapi
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.
# [WinError 3] The system cannot find the path specified: '/content/trainingdemo/pre-trained-models'
# D:\_z_\Anaconda_Projects\_______temporary\cocoapi
# python: can't open file 'D:\\_z_\\Anaconda_Projects\\_______temporary\\cocoapi\\object_detection\\builders\\model_builder_tf2_test.py': [Errno 2] No such file or directory
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# [WinError 3] The system cannot find the path specified: '/content/trainingdemo'
# D:\_z_\Anaconda_Projects\_______temporary\cocoapi
# tar: Error opening archive: Failed to open 'ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz'
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
# python: can't open file 'D:\\_z_\\Anaconda_Projects\\_______temporary\\cocoapi\\generate_tfrecord.py': [Errno 2] No such file or directory
# [WinError 3] The system cannot find the path specified: '/content/trainingdemo'
# D:\_z_\Anaconda_Projects\_______temporary\cocoapi
# python: can't open file 'D:\\_z_\\Anaconda_Projects\\_______temporary\\cocoapi\\generate_tfrecord.py': [Errno 2] No such file or directory
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
# [WinError 3] The system cannot find the path specified: '/content/trainingdemo'
# D:\_z_\Anaconda_Projects\_______temporary\cocoapi
# python: can't open file 'D:\\_z_\\Anaconda_Projects\\_______temporary\\cocoapi\\model_main_tf2.py': [Errno 2] No such file or directory
# python: can't open file 'D:\\_z_\\Anaconda_Projects\\_______temporary\\cocoapi\\exporter_main_v2.py': [Errno 2] No such file or directory

# %%
pip install tensorflow-object-detection-api
# Out:
# Collecting tensorflow-object-detection-api
#   Downloading tensorflow_object_detection_api-0.1.1.tar.gz (577 kB)
#      ---------------------------------------- 0.0/577.4 kB ? eta -:--:--
#      - ----------------------------------- 20.5/577.4 kB 330.3 kB/s eta 0:00:02
#      -- ---------------------------------- 41.0/577.4 kB 393.8 kB/s eta 0:00:02
#      ---- -------------------------------- 71.7/577.4 kB 558.5 kB/s eta 0:00:01
#      ------------- ------------------------ 204.8/577.4 kB 1.1 MB/s eta 0:00:01
#      --------------------- ---------------- 327.7/577.4 kB 1.4 MB/s eta 0:00:01
#      -------------------------- ----------- 409.6/577.4 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 577.4/577.4 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Pillow>=1.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-object-detection-api) (10.2.0)
# Requirement already satisfied: Matplotlib>=2.1 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-object-detection-api) (3.8.0)
# Collecting Cython>=0.28.1 (from tensorflow-object-detection-api)
#   Obtaining dependency information for Cython>=0.28.1 from https://files.pythonhosted.org/packages/18/ec/f47a721071d084d6c2b6783eb8d058b964b1450cb708d920d0d792f42001/Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: Protobuf in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-object-detection-api) (3.20.3)
# Collecting lxml (from tensorflow-object-detection-api)
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/df/c5/8b05e69685b48cf11b596fbdd466f76cb3c1e3efe0361d8be0edb9df0325/lxml-5.2.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading lxml-5.2.1-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: jupyter in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: tensorflow in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-object-detection-api) (2.16.1)
# Collecting contextlib2 (from tensorflow-object-detection-api)
#   Obtaining dependency information for contextlib2 from https://files.pythonhosted.org/packages/76/56/6d6872f79d14c0cb02f1646cbb4592eef935857c0951a105874b7b62a0c3/contextlib2-21.6.0-py2.py3-none-any.whl.metadata
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: wheel in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-object-detection-api) (0.38.4)
# Collecting twine (from tensorflow-object-detection-api)
#   Obtaining dependency information for twine from https://files.pythonhosted.org/packages/9a/d4/4db90c4a2b8c1006ea3e6291f36b50b66e45887cf17b3b958b5d646fb837/twine-5.0.0-py3-none-any.whl.metadata
#   Downloading twine-5.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\_z_\anaconda_projects\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\_z_\anaconda_projects\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\_z_\anaconda_projects\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\_z_\anaconda_projects\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in d:\_z_\anaconda_projects\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in d:\_z_\anaconda_projects\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\_z_\anaconda_projects\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (2.8.2)
# Requirement already satisfied: notebook in d:\_z_\anaconda_projects\lib\site-packages (from jupyter->tensorflow-object-detection-api) (7.0.8)
# Requirement already satisfied: qtconsole in d:\_z_\anaconda_projects\lib\site-packages (from jupyter->tensorflow-object-detection-api) (5.5.1)
# Requirement already satisfied: jupyter-console in d:\_z_\anaconda_projects\lib\site-packages (from jupyter->tensorflow-object-detection-api) (6.6.3)
# Requirement already satisfied: nbconvert in d:\_z_\anaconda_projects\lib\site-packages (from jupyter->tensorflow-object-detection-api) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from jupyter->tensorflow-object-detection-api) (6.25.2)
# Requirement already satisfied: ipywidgets in d:\_z_\anaconda_projects\lib\site-packages (from jupyter->tensorflow-object-detection-api) (8.1.2)
# Requirement already satisfied: tensorflow-intel==2.16.1 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.3.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2.31.0)
# Requirement already satisfied: setuptools in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\_z_\anaconda_projects\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.31.0)
# Requirement already satisfied: pkginfo>=1.8.1 in d:\_z_\anaconda_projects\lib\site-packages (from twine->tensorflow-object-detection-api) (1.9.6)
# Collecting readme-renderer>=35.0 (from twine->tensorflow-object-detection-api)
#   Obtaining dependency information for readme-renderer>=35.0 from https://files.pythonhosted.org/packages/45/be/3ea20dc38b9db08387cf97997a85a7d51527ea2057d71118feb0aa8afa55/readme_renderer-43.0-py3-none-any.whl.metadata
#   Downloading readme_renderer-43.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in d:\_z_\anaconda_projects\lib\site-packages (from twine->tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in d:\_z_\anaconda_projects\lib\site-packages (from twine->tensorflow-object-detection-api) (2.1.0)
# Requirement already satisfied: importlib-metadata>=3.6 in d:\_z_\anaconda_projects\lib\site-packages (from twine->tensorflow-object-detection-api) (7.0.1)
# Requirement already satisfied: keyring>=15.1 in d:\_z_\anaconda_projects\lib\site-packages (from twine->tensorflow-object-detection-api) (24.3.1)
# Collecting rfc3986>=1.4.0 (from twine->tensorflow-object-detection-api)
#   Obtaining dependency information for rfc3986>=1.4.0 from https://files.pythonhosted.org/packages/ff/9a/9afaade874b2fa6c752c36f1548f718b5b83af81ed9b76628329dab81c1b/rfc3986-2.0.0-py2.py3-none-any.whl.metadata
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: rich>=12.0.0 in d:\_z_\anaconda_projects\lib\site-packages (from twine->tensorflow-object-detection-api) (13.7.1)
# Requirement already satisfied: zipp>=0.5 in d:\_z_\anaconda_projects\lib\site-packages (from importlib-metadata>=3.6->twine->tensorflow-object-detection-api) (3.17.0)
# Requirement already satisfied: jaraco.classes in d:\_z_\anaconda_projects\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in d:\_z_\anaconda_projects\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (0.2.2)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->tensorflow-object-detection-api)
#   Obtaining dependency information for nh3>=0.2.14 from https://files.pythonhosted.org/packages/9d/52/ebab65758efae7980b15cdea290f0957ac3b25df6cbc098d9747c2b02bd3/nh3-0.2.17-cp37-abi3-win_amd64.whl.metadata
#   Downloading nh3-0.2.17-cp37-abi3-win_amd64.whl.metadata (1.8 kB)
# Collecting docutils>=0.13.1 (from readme-renderer>=35.0->twine->tensorflow-object-detection-api)
#   Obtaining dependency information for docutils>=0.13.1 from https://files.pythonhosted.org/packages/8f/d7/9322c609343d929e75e7e5e6255e614fcc67572cfd083959cdef3b7aad79/docutils-0.21.2-py3-none-any.whl.metadata
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (2.16.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\_z_\anaconda_projects\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\_z_\anaconda_projects\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\_z_\anaconda_projects\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\_z_\anaconda_projects\lib\site-packages (from rich>=12.0.0->twine->tensorflow-object-detection-api) (3.0.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.5.8)
# Requirement already satisfied: psutil in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in d:\_z_\anaconda_projects\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in d:\_z_\anaconda_projects\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in d:\_z_\anaconda_projects\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (3.0.10)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter->tensorflow-object-detection-api) (3.0.39)
# Requirement already satisfied: beautifulsoup4 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (4.1.0)
# Requirement already satisfied: defusedxml in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (3.1.3)
# Requirement already satisfied: jupyterlab-pygments in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.5.0)
# Requirement already satisfied: tinycss2 in d:\_z_\anaconda_projects\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.2.1)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for jupyter-server<3,>=2.4.0 from https://files.pythonhosted.org/packages/07/46/6bb926b3bf878bf687b952fb6a4c09d014b4575a25960f2cd1a61793763f/jupyter_server-2.14.0-py3-none-any.whl.metadata
#   Downloading jupyter_server-2.14.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in d:\_z_\anaconda_projects\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in d:\_z_\anaconda_projects\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in d:\_z_\anaconda_projects\lib\site-packages (from notebook->jupyter->tensorflow-object-detection-api) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in d:\_z_\anaconda_projects\lib\site-packages (from qtconsole->jupyter->tensorflow-object-detection-api) (2.4.1)
# Requirement already satisfied: webencodings in d:\_z_\anaconda_projects\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->tensorflow-object-detection-api) (0.5.1)
# Requirement already satisfied: backcall in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: decorator in d:\_z_\anaconda_projects\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.19.0)
# Requirement already satisfied: pickleshare in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.6.2)
# Requirement already satisfied: colorama in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tensorflow-object-detection-api) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tensorflow-object-detection-api) (306)
# Requirement already satisfied: anyio>=3.1.0 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (3.7.1)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (21.3.0)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for jupyter-events>=0.9.0 from https://files.pythonhosted.org/packages/a5/94/059180ea70a9a326e1815176b2370da56376da347a796f8c4f0b830208ef/jupyter_events-0.10.0-py3-none-any.whl.metadata
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.17.1)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for websocket-client>=1.7 from https://files.pythonhosted.org/packages/5a/84/44687a29792a70e111c5c477230a72c4b957d88d16141199bf9acb7537a3/websocket_client-1.8.0-py3-none-any.whl.metadata
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: async-lru>=1.0.0 in d:\_z_\anaconda_projects\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter->tensorflow-object-detection-api) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\_z_\anaconda_projects\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter->tensorflow-object-detection-api) (2.2.0)
# Requirement already satisfied: babel>=2.10 in d:\_z_\anaconda_projects\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in d:\_z_\anaconda_projects\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\_z_\anaconda_projects\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (4.19.2)
# Requirement already satisfied: namex in d:\_z_\anaconda_projects\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.0.7)
# Requirement already satisfied: optree in d:\_z_\anaconda_projects\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.10.0)
# Requirement already satisfied: mdurl~=0.1 in d:\_z_\anaconda_projects\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->tensorflow-object-detection-api) (0.1.2)
# Requirement already satisfied: fastjsonschema in d:\_z_\anaconda_projects\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->tensorflow-object-detection-api) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->tensorflow-object-detection-api) (0.2.6)
# Requirement already satisfied: markdown>=2.6.8 in d:\_z_\anaconda_projects\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\_z_\anaconda_projects\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\_z_\anaconda_projects\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->tensorflow-object-detection-api) (3.0.1)
# Requirement already satisfied: soupsieve>1.2 in d:\_z_\anaconda_projects\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->tensorflow-object-detection-api) (2.5)
# Requirement already satisfied: more-itertools in d:\_z_\anaconda_projects\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->tensorflow-object-detection-api) (10.1.0)
# Requirement already satisfied: sniffio>=1.1 in d:\_z_\anaconda_projects\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in d:\_z_\anaconda_projects\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in d:\_z_\anaconda_projects\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\_z_\anaconda_projects\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\_z_\anaconda_projects\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\_z_\anaconda_projects\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\_z_\anaconda_projects\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (6.0.1)
# Requirement already satisfied: rfc3339-validator in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\_z_\anaconda_projects\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (0.1.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\harisanju\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.2)
# Collecting fqdn (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for fqdn from https://files.pythonhosted.org/packages/cf/58/8acf1b3e91c58313ce5cb67df61001fc9dcd21be4fadb76c1a2d540e09ed/fqdn-1.5.1-py3-none-any.whl.metadata
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for isoduration from https://files.pythonhosted.org/packages/7b/55/e5326141505c5d5e34c5e0935d2908a74e4561eca44108fbfb9c13d2911a/isoduration-20.11.0-py3-none-any.whl.metadata
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in d:\_z_\anaconda_projects\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api) (2.1)
# Collecting uri-template (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for uri-template from https://files.pythonhosted.org/packages/e7/00/3fca040d7cf8a32776d3d81a00c8ee7457e00f80c649f1e4a863c8321ae9/uri_template-1.3.0-py3-none-any.whl.metadata
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for webcolors>=1.11 from https://files.pythonhosted.org/packages/d5/e1/3e9013159b4cbb71df9bd7611cbf90dc2c621c8aeeb677fc41dad72f2261/webcolors-1.13-py3-none-any.whl.metadata
#   Downloading webcolors-1.13-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in d:\_z_\anaconda_projects\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (1.16.0)
# Requirement already satisfied: pycparser in d:\_z_\anaconda_projects\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->tensorflow-object-detection-api) (2.21)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for arrow>=0.15.0 from https://files.pythonhosted.org/packages/f8/ed/e97229a566617f2ae958a6b13e7cc0f585470eac730a73e9e82c32a3cdd2/arrow-1.3.0-py3-none-any.whl.metadata
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->tensorflow-object-detection-api)
#   Obtaining dependency information for types-python-dateutil>=2.8.10 from https://files.pythonhosted.org/packages/c7/1b/af4f4c4f3f7339a4b7eb3c0ab13416db98f8ac09de3399129ee5fdfa282b/types_python_dateutil-2.9.0.20240316-py3-none-any.whl.metadata
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl.metadata (1.8 kB)
# Downloading Cython-3.0.10-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.8 MB 3.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.8 MB 4.1 MB/s eta 0:00:01
#    ------ --------------------------------- 0.5/2.8 MB 3.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/2.8 MB 3.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.8/2.8 MB 3.7 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.8 MB 3.5 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/2.8 MB 3.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.2/2.8 MB 3.1 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.8 MB 3.0 MB/s eta 0:00:01
#    --------------------- ------------------ 1.5/2.8 MB 3.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 3.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.8 MB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.0/2.8 MB 2.9 MB/s eta 0:00:01
#    ------------------------------- -------- 2.2/2.8 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 2.3/2.8 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.8 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 3.0 MB/s eta 0:00:00
# Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Downloading lxml-5.2.1-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/3.8 MB 6.1 MB/s eta 0:00:01
#    --- ------------------------------------ 0.3/3.8 MB 754.8 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.4/3.8 MB 902.2 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.6/3.8 MB 992.2 kB/s eta 0:00:04
#    ------ --------------------------------- 0.6/3.8 MB 965.4 kB/s eta 0:00:04
#    ------- -------------------------------- 0.7/3.8 MB 1.1 MB/s eta 0:00:03
#    ------- -------------------------------- 0.7/3.8 MB 1.1 MB/s eta 0:00:03
#    -------- ------------------------------- 0.8/3.8 MB 663.6 kB/s eta 0:00:05
#    --------- ------------------------------ 0.9/3.8 MB 694.8 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/3.8 MB 610.6 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/3.8 MB 504.5 kB/s eta 0:00:06
#    ----------- ---------------------------- 1.1/3.8 MB 516.2 kB/s eta 0:00:06
#    ----------- ---------------------------- 1.1/3.8 MB 506.4 kB/s eta 0:00:06
#    ------------ --------------------------- 1.2/3.8 MB 532.5 kB/s eta 0:00:05
#    ------------- -------------------------- 1.3/3.8 MB 506.1 kB/s eta 0:00:05
#    -------------- ------------------------- 1.4/3.8 MB 535.1 kB/s eta 0:00:05
#    --------------- ------------------------ 1.5/3.8 MB 537.1 kB/s eta 0:00:05
#    ---------------- ----------------------- 1.6/3.8 MB 576.6 kB/s eta 0:00:04
#    ------------------ --------------------- 1.7/3.8 MB 622.0 kB/s eta 0:00:04
#    ------------------- -------------------- 1.9/3.8 MB 651.5 kB/s eta 0:00:04
#    --------------------- ------------------ 2.0/3.8 MB 705.3 kB/s eta 0:00:03
#    ---------------------- ----------------- 2.1/3.8 MB 732.7 kB/s eta 0:00:03
#    ---------------------- ----------------- 2.2/3.8 MB 728.0 kB/s eta 0:00:03
#    ------------------------ --------------- 2.3/3.8 MB 774.8 kB/s eta 0:00:02
#    -------------------------- ------------- 2.5/3.8 MB 820.0 kB/s eta 0:00:02
#    --------------------------- ------------ 2.6/3.8 MB 793.2 kB/s eta 0:00:02
#    --------------------------- ------------ 2.6/3.8 MB 793.2 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.7/3.8 MB 798.5 kB/s eta 0:00:02
#    ----------------------------- ---------- 2.8/3.8 MB 836.5 kB/s eta 0:00:02
#    ------------------------------- -------- 3.0/3.8 MB 860.8 kB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 883.6 kB/s eta 0:00:01
#    --------------------------------- ------ 3.2/3.8 MB 904.6 kB/s eta 0:00:01
#    ---------------------------------- ----- 3.3/3.8 MB 911.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 3.3/3.8 MB 910.5 kB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 918.4 kB/s eta 0:00:01
#    ------------------------------------ --- 3.5/3.8 MB 937.6 kB/s eta 0:00:01
#    ------------------------------------- -- 3.6/3.8 MB 896.8 kB/s eta 0:00:01
#    -------------------------------------- - 3.6/3.8 MB 908.8 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 907.3 kB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 926.1 kB/s eta 0:00:00
# Downloading twine-5.0.0-py3-none-any.whl (37 kB)
# Downloading readme_renderer-43.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.4 kB ? eta -:--:--
#    ------ --------------------------------- 92.2/587.4 kB 1.7 MB/s eta 0:00:01
#    ------------------ --------------------- 276.5/587.4 kB 2.4 MB/s eta 0:00:01
#    ------------------------- -------------- 368.6/587.4 kB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 440.3/587.4 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  573.4/587.4 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 587.4/587.4 kB 2.2 MB/s eta 0:00:00
# Downloading jupyter_server-2.14.0-py3-none-any.whl (383 kB)
#    ---------------------------------------- 0.0/383.3 kB ? eta -:--:--
#    ------------ --------------------------- 122.9/383.3 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 327.7/383.3 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 383.3/383.3 kB 3.4 MB/s eta 0:00:00
# Downloading nh3-0.2.17-cp37-abi3-win_amd64.whl (571 kB)
#    ---------------------------------------- 0.0/571.5 kB ? eta -:--:--
#    ------------------- -------------------- 276.5/571.5 kB 5.8 MB/s eta 0:00:01
#    ------------------------------ --------- 440.3/571.5 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 571.5/571.5 kB 5.1 MB/s eta 0:00:00
# Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#    ---------------------------------------- 58.8/58.8 kB 3.2 MB/s eta 0:00:00
# Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#    ---------------------------------------- 66.4/66.4 kB ? eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Building wheels for collected packages: tensorflow-object-detection-api
#   Building wheel for tensorflow-object-detection-api (setup.py): started
#   Building wheel for tensorflow-object-detection-api (setup.py): finished with status 'done'
#   Created wheel for tensorflow-object-detection-api: filename=tensorflow_object_detection_api-0.1.1-py3-none-any.whl size=844499 sha256=ff0740219b2ac8e872631d35a73c26bbdfcad4cabe21aba4e69fd5d83f154182
#   Stored in directory: c:\users\harisanju\appdata\local\pip\cache\wheels\cf\4f\d0\e711451dedf65c9f1d357a34438b4d26fb24a819a22d58a9a6
# Successfully built tensorflow-object-detection-api
# Installing collected packages: nh3, websocket-client, webcolors, uri-template, types-python-dateutil, rfc3986, lxml, fqdn, docutils, Cython, contextlib2, readme-renderer, arrow, twine, isoduration, jupyter-events, jupyter-server, tensorflow-object-detection-api
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Uninstalling websocket-client-0.58.0:
#       Successfully uninstalled websocket-client-0.58.0
#   Attempting uninstall: jupyter-events
#     Found existing installation: jupyter-events 0.8.0
#     Uninstalling jupyter-events-0.8.0:
#       Successfully uninstalled jupyter-events-0.8.0
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# Successfully installed Cython-3.0.10 arrow-1.3.0 contextlib2-21.6.0 docutils-0.21.2 fqdn-1.5.1 isoduration-20.11.0 jupyter-events-0.10.0 jupyter-server-2.10.0 lxml-5.2.1 nh3-0.2.17 readme-renderer-43.0 rfc3986-2.0.0 tensorflow-object-detection-api-0.1.1 twine-5.0.0 types-python-dateutil-2.9.0.20240316 uri-template-1.3.0 webcolors-1.13 websocket-client-1.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import cv2
import argparse
import cv2
# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# PROVIDE PATH TO IMAGE DIRECTORY
IMAGE_PATHS = '/content/training_demo/images/train/image1.jpg'
# PROVIDE PATH TO MODEL DIRECTORY
PATH_TO_MODEL_DIR = '/content/training_demo/exported_models/my_model'
# PROVIDE PATH TO LABEL MAP
PATH_TO_LABELS = '/content/training_demo/annotations/label_map.pbtxt'
# PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
MIN_CONF_THRESH = float(0.60)
# LOAD THE MODEL
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"
print('Loading model...', end='')
start_time = time.time()
# LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)
end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# LOAD LABEL MAP DATA FOR PLOTTING
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore') # Suppress Matplotlib warnings
def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
        path: the file path to the image
    Returns:
        uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))
print('Running inference for {}... '.format(IMAGE_PATHS), end='')
image = cv2.imread(IMAGE_PATHS)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_expanded = np.expand_dims(image_rgb, axis=0)
# The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
input_tensor = tf.convert_to_tensor(image)
# The model expects a batch of images, so add an axis with `tf.newaxis`.
input_tensor = input_tensor[tf.newaxis, ...]
# input_tensor = np.expand_dims(image_np, 0)
detections = detect_fn(input_tensor)
# All outputs are batches tensors.
# Convert to numpy arrays, and take index [0] to remove the batch dimension.
# We're only interested in the first num_detections.
num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy() for key, value in detections.items()}
detections['num_detections'] = num_detections
# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)
image_with_detections = image.copy()
# SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
viz_utils.visualize_boxes_and_labels_on_image_array(
    image_with_detections,
    detections['detection_boxes'],
    detections['detection_classes'],
    detections['detection_scores'],
    category_index,
    use_normalized_coordinates=True,
    max_boxes_to_draw=200,
    min_score_thresh=0.5,
    agnostic_mode=False)
print('Done')
cv2.imshow('image_with_detections', image_with_detections)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 22
#      20 # LOAD THE MODEL
#      21 import time
# ---> 22 from object_detection.utils import label_map_util
#      23 from object_detection.utils import visualization_utils as viz_utils
#      24 PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"
#
# File D:\_z_\Anaconda_Projects\Lib\site-packages\object_detection\utils\label_map_util.py:21
#      19 import tensorflow as tf
#      20 from google.protobuf import text_format
# ---> 21 from object_detection.protos import string_int_label_map_pb2
#      24 def _validate_label_map(label_map):
#      25   """Checks if a label map is valid.
#      26
#      27   Args:
#    (...)
#      31     ValueError: if label map is invalid.
#      32   """
#
# File D:\_z_\Anaconda_Projects\Lib\site-packages\object_detection\protos\string_int_label_map_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='object_detection/protos/string_int_label_map.proto',
#      20   package='object_detection.protos',
#    (...)
#      23   serialized_pb=_b('\n2object_detection/protos/string_int_label_map.proto\x12\x17object_detection.protos\"G\n\x15StringIntLabelMapItem\x12\x0c\n\x04name\x18\x01 \x01(\t\x12\n\n\x02id\x18\x02 \x01(\x05\x12\x14\n\x0c\x64isplay_name\x18\x03 \x01(\t\"Q\n\x11StringIntLabelMap\x12<\n\x04item\x18\x01 \x03(\x0b\x32..object_detection.protos.StringIntLabelMapItem')
#      24 )
#      29 _STRINGINTLABELMAPITEM = _descriptor.Descriptor(
#      30   name='StringIntLabelMapItem',
#      31   full_name='object_detection.protos.StringIntLabelMapItem',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='name', full_name='object_detection.protos.StringIntLabelMapItem.name', index=0,
#      38       number=1, type=9, cpp_type=9, label=1,
#      39       has_default_value=False, default_value=_b("").decode('utf-8'),
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='id', full_name='object_detection.protos.StringIntLabelMapItem.id', index=1,
#      45       number=2, type=5, cpp_type=1, label=1,
#      46       has_default_value=False, default_value=0,
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50     _descriptor.FieldDescriptor(
#      51       name='display_name', full_name='object_detection.protos.StringIntLabelMapItem.display_name', index=2,
#      52       number=3, type=9, cpp_type=9, label=1,
#      53       has_default_value=False, default_value=_b("").decode('utf-8'),
#      54       message_type=None, enum_type=None, containing_type=None,
#      55       is_extension=False, extension_scope=None,
#      56       serialized_options=None, file=DESCRIPTOR),
#      57   ],
#      58   extensions=[
#      59   ],
#      60   nested_types=[],
#      61   enum_types=[
#      62   ],
#      63   serialized_options=None,
#      64   is_extendable=False,
#      65   syntax='proto2',
#      66   extension_ranges=[],
#      67   oneofs=[
#      68   ],
#      69   serialized_start=79,
#      70   serialized_end=150,
#      71 )
#      74 _STRINGINTLABELMAP = _descriptor.Descriptor(
#      75   name='StringIntLabelMap',
#      76   full_name='object_detection.protos.StringIntLabelMap',
#    (...)
#     101   serialized_end=233,
#     102 )
#     104 _STRINGINTLABELMAP.fields_by_name['item'].message_type = _STRINGINTLABELMAPITEM
#
# File D:\_z_\Anaconda_Projects\Lib\site-packages\google\protobuf\descriptor.py:553, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     547 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     548             default_value, message_type, enum_type, containing_type,
#     549             is_extension, extension_scope, options=None,
#     550             serialized_options=None,
#     551             has_default_value=True, containing_oneof=None, json_name=None,
#     552             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 553   _message.Message._CheckCalledFromGeneratedFile()
#     554   if is_extension:
#     555     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
